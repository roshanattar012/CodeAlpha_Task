# %% [markdown]
# ## Web Scraping
# # CodeAlpha - Web Scraping Project
#
# ## Project Title
# Smart Product Data Web Scraper using Python
#
# ## Description
# This project demonstrates web scraping using Python by extracting product information from a website. The scraper collects product details such as title, price, and ratings automatically and stores them in a structured dataset.
#
# The project includes:
# - Website connection
# - HTML parsing
# - Data extraction
# - CSV dataset generation
# - Basic visualization
#
# ## Technologies Used
# - Python
# - Requests
# - BeautifulSoup
# - Pandas
# - Matplotlib
# - Seaborn
# - Jupyter Notebook
#
# ## Features
# - Automated data collection
# - Product information extraction
# - CSV file generation
# - Ratings analysis
# - Visualization of scraped data
#
# ## Objective
# The objective of this project is to automate data collection from websites and prepare datasets for analytics and visualization tasks.
#
# ## Author
# Roshan Attar
# ```

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/"

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, 'html.parser')

print(soup.title.text)
# Out:
#     All products | Books to Scrape - Sandbox

# %%
books = soup.find_all('article', class_='product_pod')

print("Total Books Found:", len(books))
# Out:
# Total Books Found: 20

# %%
titles = []
prices = []
ratings = []

for book in books:
    
    title = book.h3.a['title']
    
    price = book.find('p', class_='price_color').text
    
    rating = book.p['class'][1]
    
    titles.append(title)
    prices.append(price)
    ratings.append(rating)

# %%
df = pd.DataFrame({
    'Title': titles,
    'Price': prices,
    'Rating': ratings
})

df.head()
# Out:
#                                    Title    Price Rating
# 0                   A Light in the Attic  Â£51.77  Three
# 1                     Tipping the Velvet  Â£53.74    One
# 2                             Soumission  Â£50.10    One
# 3                          Sharp Objects  Â£47.82   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five

# %%
df.to_csv("scraped_books_data.csv", index=False)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully

# %%
print(df['Rating'].value_counts())
# Out:
# Rating
# One      6
# Four     4
# Five     4
# Three    3
# Two      3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7,5))

sns.countplot(x='Rating', data=df)

plt.title("Book Ratings Distribution")

plt.show()

# %% [markdown]
# # Insights
#
# 1. Web scraping automates data collection.
# 2. Product ratings can be analyzed for customer trends.
# 3. Scraped datasets are useful for EDA and visualization tasks.
# 4. Python libraries make data extraction efficient.
